# %%
# Q 1 answer
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('youtube_dislike_dataset.csv')
df
# Out:
#           video_id                                              title  \
# 0      --0bCF-iK2E               Jadon Sancho  Magical Skills & Goals
# 1      --14w5SOEUs                 Migos - Avalanche (Official Video)
# 2      --40TEbZ9Is         Supporting Actress in a Comedy: 73rd Emmys
# 3      --4tfbSyYDE            JO1'YOUNG (JO1 ver.)' PERFORMANCE VIDEO
# 4      --DKkzWVh-E                       Why Retaining Walls Collapse
# ...            ...                                                ...
# 37417  zzd4ydafGR0  Lil Tjay - Calling My Phone (feat. 6LACK) [Off...
# 37418  zziBybeSAtw  PELICANS at LAKERS | FULL GAME HIGHLIGHTS | Ja...
# 37419  zzk09ESX7e0                 [MV]  (MAMAMOO) - Where Are We Now
# 37420  zzmQEb0Em5I              FELLIPE ESCUDERO- Master Podcast  #12
# 37421  zzxPZwaA-8w  Gareth Bale brace secures dramatic comeback on...
#
#                      channel_id          channel_title         published_at  \
# ...

# %%
#Top five dataset
df.head()
# Out:
#       video_id                                       title  \
# 0  --0bCF-iK2E        Jadon Sancho  Magical Skills & Goals
# 1  --14w5SOEUs          Migos - Avalanche (Official Video)
# 2  --40TEbZ9Is  Supporting Actress in a Comedy: 73rd Emmys
# 3  --4tfbSyYDE     JO1'YOUNG (JO1 ver.)' PERFORMANCE VIDEO
# 4  --DKkzWVh-E                Why Retaining Walls Collapse
#
#                  channel_id          channel_title         published_at  \
# 0  UC6UL29enLNe4mqwTfAyeNuw             Bundesliga  2021-07-01 10:00:00
# 1  UCGIelM2Dj3zza3xyV3pL3WQ              MigosVEVO  2021-06-10 16:00:00
# 2  UClBKH8yZRcM4AsRjDVEdjMg     Television Academy  2021-09-20 01:03:32
# 3  UCsmXiDP8S40uBeJYxvyulmA                    JO1  2021-03-03 10:00:17
# 4  UCMOqf8ab-42UUQIdVoKwjlQ  Practical Engineering  2021-12-07 13:00:00
#
#    view_count   likes  dislikes  comment_count  \
# 0     1048888   19515       226           1319
# 1    15352638  359277      7479          18729
# ...

# %%
#Bottom five dataset
df.tail()
# Out:
#           video_id                                              title  \
# 37417  zzd4ydafGR0  Lil Tjay - Calling My Phone (feat. 6LACK) [Off...
# 37418  zziBybeSAtw  PELICANS at LAKERS | FULL GAME HIGHLIGHTS | Ja...
# 37419  zzk09ESX7e0                 [MV]  (MAMAMOO) - Where Are We Now
# 37420  zzmQEb0Em5I              FELLIPE ESCUDERO- Master Podcast  #12
# 37421  zzxPZwaA-8w  Gareth Bale brace secures dramatic comeback on...
#
#                      channel_id      channel_title         published_at  \
# 37417  UCEB4a5o_6KfjxHwNMnmj54Q           Lil Tjay  2021-02-12 05:03:49
# 37418  UCWJ2lWNubArHWmf3FIHbfcQ                NBA  2021-01-16 05:39:05
# 37419  UCuhAUMLzJxlP1W7mEk0_6lA            MAMAMOO  2021-06-02 09:00:10
# 37420  UC8NjnNWMsRqq11NYvHAQb1g     Master Podcast  2020-10-20 20:59:30
# 37421  UCEg25rdRZXg32iwai6N6l0w  Tottenham Hotspur  2021-05-23 21:00:31
#
#        view_count    likes  dislikes  comment_count  \
# 37417   120408275  2180780     35871          81360
# ...

# %%
#Q 2 answer
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37422 entries, 0 to 37421
# Data columns (total 12 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   video_id       37422 non-null  object
#  1   title          37422 non-null  object
#  2   channel_id     37422 non-null  object
#  3   channel_title  37422 non-null  object
#  4   published_at   37422 non-null  object
#  5   view_count     37422 non-null  int64
#  6   likes          37422 non-null  int64
#  7   dislikes       37422 non-null  int64
#  8   comment_count  37422 non-null  int64
#  9   tags           37422 non-null  object
#  10  description    37422 non-null  object
#  11  comments       37264 non-null  object
# dtypes: int64(4), object(8)
# memory usage: 3.4+ MB

# %%
#Q 2 answer
df.shape
# Out:
# (37422, 12)

# %%
"""so according to the given data set, there are in total (12) columns and out of those (12) columns (8)columns
have the datatype as object and the remaining (4) columns have the datatype as integer. And the shape of the dataset 
shows that there are 37422 rows and 12 columns in this dataset."""
# Out:
# 'so according to the given data set, there are in total (12) columns and out of those (12) columns (8)columns\nhave the datatype as object and the remaining (4) columns have the datatype as integer. And the shape of the dataset \nshows that there are 37422 rows and 12 columns in this dataset.'

# %%
#Q 3 answer
percentage_missing = df.isnull().sum()*100/len(df)
percentage_missing
# Out:
# video_id         0.000000
# title            0.000000
# channel_id       0.000000
# channel_title    0.000000
# published_at     0.000000
# view_count       0.000000
# likes            0.000000
# dislikes         0.000000
# comment_count    0.000000
# tags             0.000000
# description      0.000000
# comments         0.422212
# dtype: float64

# %%
# The missing values can be dropped by the following 
df_without_missing_rows = df.dropna()
df_without_missing_rows
# There were 37422 rows initially and after being dropped there are 37262 rows.
# Out:
#           video_id                                              title  \
# 0      --0bCF-iK2E               Jadon Sancho  Magical Skills & Goals
# 1      --14w5SOEUs                 Migos - Avalanche (Official Video)
# 2      --40TEbZ9Is         Supporting Actress in a Comedy: 73rd Emmys
# 3      --4tfbSyYDE            JO1'YOUNG (JO1 ver.)' PERFORMANCE VIDEO
# 4      --DKkzWVh-E                       Why Retaining Walls Collapse
# ...            ...                                                ...
# 37417  zzd4ydafGR0  Lil Tjay - Calling My Phone (feat. 6LACK) [Off...
# 37418  zziBybeSAtw  PELICANS at LAKERS | FULL GAME HIGHLIGHTS | Ja...
# 37419  zzk09ESX7e0                 [MV]  (MAMAMOO) - Where Are We Now
# 37420  zzmQEb0Em5I              FELLIPE ESCUDERO- Master Podcast  #12
# 37421  zzxPZwaA-8w  Gareth Bale brace secures dramatic comeback on...
#
#                      channel_id          channel_title         published_at  \
# ...

# %%
# Q 4 answer
df.describe(include = 'all')
# Out:
#            video_id  title                channel_id        channel_title  \
# count         37422  37422                     37422                37422
# unique        37422  37113                     10961                10883
# top     --0bCF-iK2E    www  UCNAf1k0yIjyGu3k9BwAg3lg  Sky Sports Football
# freq              1     21                       533                  533
# mean            NaN    NaN                       NaN                  NaN
# std             NaN    NaN                       NaN                  NaN
# min             NaN    NaN                       NaN                  NaN
# 25%             NaN    NaN                       NaN                  NaN
# 50%             NaN    NaN                       NaN                  NaN
# 75%             NaN    NaN                       NaN                  NaN
# max             NaN    NaN                       NaN                  NaN
#
#                published_at    view_count         likes      dislikes  \
# ...

# %%
# Q 4 answer
"""The describe function (include = 'all') means it includes the numeric as well as the string values 
including the null values.

Usually the describe function by default includes only the numeric values. In the above given dataset, 
it shows count,mean,std,min and max values.There are NaN values too which means they are either missing 
or null values which can be converted only into float datatype.There are three percetile values as well: 
25% , 50% ,and 75%. 25% means 25% of your data have the value 1.00 or below. 50% means 50% of your data 
have the value 1.5 or below. 75% means 75% of your data have the value 2.25 or below."""

# %%
# Q 4 answer This is for finding the categorical count
categorical_summary = {}
for col in df.select_dtypes(include='object').columns:
    categorical_summary[col] = df[col].value_counts()

print("\nCount and Frequency of Categorical Columns:")
for col, summary in categorical_summary.items():
    print(f"\nColumn: {col}")
    print(summary)
# Out:
# Count and Frequency of Categorical Columns:
#
# Column: video_id
# --0bCF-iK2E    1
# eb956E3RXfo    1
# eZc0O5Czg40    1
# e_G6eM2oq90    1
# e_Ou-HUCQ9Q    1
#               ..
# K8qeRtOPDqs    1
# K8xAit6W3Rs    1
# K95MIzDth_A    1
# K96S2qroRN4    1
# zzxPZwaA-8w    1
# Name: video_id, Length: 37422, dtype: int64
#
# Column: title
# www                                                                                                    21
# Starlink Mission                                                                                       20
# wwww                                                                                                    9
# vs                                                                                                      9
# Most Oddly Satisfying Video to watch before sleep                                                       9
#                                                                                                        ..
# ...

# %%
# Q 5 answer get the current datatype for published_at column
print("getting the current datatype for published_at column:")
print(df['published_at'].describe(datetime_is_numeric=True))

# converting the publised_at column to pandas datetime
print("\nconverting published_at column to pandas datetime")
df['published_at'] = pd.to_datetime(df['published_at'])
df['published_at'] = pd.to_datetime(df['published_at'], format =' %Y-%m-%d %H:%M:%S')
print(df.dtypes)
# Out:
# getting the current datatype for published_at column:
# count                            37422
# mean     2021-04-10 13:04:18.237827840
# min                2020-07-27 21:49:32
# 25%      2020-12-01 12:00:13.750000128
# 50%                2021-04-10 11:00:11
# 75%      2021-08-15 23:00:08.249999872
# max                2021-12-08 05:20:47
# Name: published_at, dtype: object
#
# Converting published_at column to pandas datetime
# video_id                 object
# title                    object
# channel_id               object
# channel_title            object
# published_at     datetime64[ns]
# view_count                int64
# likes                     int64
# dislikes                  int64
# comment_count             int64
# tags                     object
# description              object
# comments                 object
# dtype: object

# %%
# Q 6 answer. This question is asking to display the months only not month_name.
df['published_month'] = df['published_at'].dt.month
print(df['published_month'])
# Out:
# 0         7
# 1         6
# 2         9
# 3         3
# 4        12
#          ..
# 37417     2
# 37418     1
# 37419     6
# 37420    10
# 37421     5
# Name: published_month, Length: 37422, dtype: int64

# %%
# Q 7 answer
month_mapping_dict = {1: 'Jan', 2: 'Feb', 3: 'Mar', 4: 'Apr', 5: 'May', 6: 'Jun', 7: 'Jul', 
                 8: 'Aug', 9: 'Sep', 10: 'Oct', 11: 'Nov', 12: 'Dec'}
df['published_month'] = df['published_month'].replace(month_mapping_dict)
print(df['published_month'])
# Out:
# 0        Jul
# 1        Jun
# 2        Sep
# 3        Mar
# 4        Dec
#         ...
# 37417    Feb
# 37418    Jan
# 37419    Jun
# 37420    Oct
# 37421    May
# Name: published_month, Length: 37422, dtype: object

# %%
# Q 8 as answer
total_video_count_by_published_month = df['published_month'].value_counts()
sorted_total_video_count_by_month = total_video_count_by_published_month.sort_values(ascending=False)
print(sorted_total_video_count_by_month)
# Out:
# Oct    4991
# Sep    4880
# Nov    4851
# Aug    4262
# Dec    3072
# Jul    2340
# Jun    2316
# Mar    2258
# Feb    2137
# Apr    2126
# Jan    2108
# May    2081
# Name: published_month, dtype: int64

# %%
#Q 9 answer
total_video_id_unique_count = df['video_id'].nunique()
print("total count of unique video_id:", total_video_id_unique_count)
total_channel_id_unique_count = df['channel_id'].nunique()
print("total count of unique channel_id:", total_channel_id_unique_count)
total_channel_title_unique_count = df['channel_title'].nunique()
print("total count of unique channel_title:", total_channel_title_unique_count)
# Out:
# Count of unique video_id: 37422
# Count of unique channel_id: 10961
# Count of unique channel_title: 10883

# %%
# Q 10 answer
video_channel_count = df['channel_title'].value_counts()
top_10 = video_channel_count.head(10)
print("top 10 channels with the highest number of videos:\n", top_10)

bottom_10 = video_channel_count.tail(10)
print("\nbottom 10 channels with the lowest number of videos:\n", bottom_10)
# Out:
# top 10 channels with the highest number of videos:
#  Sky Sports Football    533
# The United Stand       301
# BT Sport               246
# NBA                    209
# NFL                    162
# WWE                    122
# SSSniperWolf            99
# SSundee                 98
# FORMULA 1               87
# NHL                     86
# Name: channel_title, dtype: int64
#
# bottom 10 channels with the lowest number of videos:
#  Eiaz                     1
# adidas                   1
# Universitetet i Agder    1
# Team Tapia               1
# TheVincentMottola        1
# Blocktrainer             1
# Movie Addicts            1
# 1 1 minute mom           1
# FLORIN CERCEL            1
# Master Podcast           1
# Name: channel_title, dtype: int64

# %%
# Q 11 answer
maximum_likes = df.loc[df['likes'].idxmax(), 'title']
print("title of the video with maximum likes:", maximum_likes)


minimum_likes = df.loc[df['likes'].idxmin(), 'title']
print("title of the video with minimum likes:", minimum_likes)
# Out:
# video title name with maximum likes: BTS () 'Dynamite' Official MV
# video title name with minimum likes: Kim Kardashian's Must-See Moments on "Saturday Night Live" | E! News

# %%
# Q 11 answer
"""
maximum_likes and minimum_likes variables hold the title of the video with maximum likes and minimum likes respectively.

This data provides insights into how the video is received by the audience, whether it is popular with the audience and 
what the content creator needs to post next time. 

If there number of likes are lower, it means the audience doesn't like the content of the video or the topic of the 
video since the video didn't connect with the audience. Maybe it is having controversial information 
for example: political or religious content. This data helps the content creator to improve or change their content next time.

If the likes are higher then the audience very much likes the video and this data can help the content creator to 
create more similar content.
"""
# Out:
# "\nmaximum_likes and minimum_likes variables hold the title of the video with maximum likes and minimum likes respectively.\n\nThis data provides insights into how the video is received by the audience, whether it is popular with the audience and \nwhat the content creator needs to post next time. \n\nIf there number of likes are lower, it means the audience doesn't like the content of the video or the topic of the \nvideo since the video didn't connect with the audience. Maybe it is having controversial information \nfor example: political or religious content. This data helps the content creator to improve or change their content next time.\n\nIf the likes are higher then the audience very much likes the video and this data can help the content creator to \ncreate more similar content.\n"

# %%
# Q 12 answer
maximum_dislikes = df.loc[df['dislikes'].idxmax(), 'title']
print("title of the video with maximum dislikes:", maximum_dislikes)


minimum_dislikes = df.loc[df['dislikes'].idxmin(), 'title']
print("title of the video with minimum dislikes:", minimum_dislikes)
# Out:
# title of the video with maximum dislikes: Cuties | Official Trailer | Netflix
# title of the video with minimum dislikes: Kim Kardashian's Must-See Moments on "Saturday Night Live" | E! News

# %%
# Q 12 answer
"""
maximum_dislikes and minimum_dislikes variables hold the title of the video with maximum dislikes and minimum dislikes respectively.

This data provides insights into how the video is received by the audience. 

If there number of dislikes are higher, it means the audience doesn't like the content of the video or the 
video is having controversial information for example: political or religious content. This data helps the 
content creator to improve their content next time.

If the dislikes are lower then the audience very much likes the video and this data can help the content creator to 
create more similar content.
"""
# Out:
# "\nmaximum_dislikes and minimum_dislikes variables hold the title of the video with maximum dislikes and minimum dislikes respectively.\n\nThis data provides insights into how the video is received by the audience. \n\nIf there number of dislikes are higher, it means the audience doesn't like the content of the video or the \nvideo is having controversial information for example: political or religious content. This data helps the \ncontent creator to improve their content next time.\n\nIf the dislikes are lower then the audience very much likes the video and this data can help the content creator to \ncreate more similar content.\n"

# %%
# Q 13 answer
correlation_coefficient = df['view_count'].corr(df['dislikes'])
print("correlation coefficient of view_count and dislikes:", correlation_coefficient)

"""
Since the correlation_coefficient value is positive indicates a positive correlation between view_count and dislikes. 

This means the number of views did have effect on how many people disliked the video. 
More the number of audience who watched the video disliked the video because it might be 
controversial or didn't match their ideology. 

Even the plot chart given below matches with this conclusion where the the number of view_count 
increases the number of dislike increases respectively
"""
# Out:
# correlation coefficient of view_count and dislikes: 0.6844687753905547
# '\nThe correlation coefficient ranges from -1 to 1. A positive value indicates a positive correlation \n(as one variable increases, the other tends to increase), while a negative value indicates a negative \ncorrelation (as one variable increases, the other tends to decrease). A value close to 0 suggests a \nweak or no linear relationship.\n\nSince the value is positive value\n'

# %%
# Q 13 answer
import matplotlib.pyplot as plt

plt.scatter(df['view_count'], df['dislikes'])
plt.xlabel('view_count')
plt.ylabel('dislikes')
plt.title('relationship between number of video views and dislikes')
plt.show()

# %%
# Q 14 answer
january_videos_info = df[df['published_month'] == 'Jan']
print(january_videos_info)
# Out:
#           video_id                                              title  \
# 27     -2Gwm7QfBnE                                    Q&A With Naisha
# 48     -4sfXSHSxzA           SURPRISING BRENT WITH HIS TIKTOK CRUSH!!
# 95     -AJD1Fc5rpQ  WE ARE HAVING A BABY! | finding out i'm pregna...
# 103    -AuJiwjsmWk              Do Ugly Foods Taste Worse? Taste Test
# 182    -JhqO2KWr5U                                   Schlatt gets fit
# ...            ...                                                ...
# 37300  zmzFL5bG-jc  DEVINE MON PERSONNAGE AVANT AKINATOR ! (c'est ...
# 37329  zpzjex7qwrA  Lampard Sacked Within Days Rorys Misery | Chel...
# 37345  zqyv-B6mnBM                 Lil Wayne - Ain't Got Time (Audio)
# 37383  zwfu1-24T7Q  PRADA Cup Day 1 | Full Race Replay | PRADA Cup...
# 37418  zziBybeSAtw  PELICANS at LAKERS | FULL GAME HIGHLIGHTS | Ja...
#
#                      channel_id       channel_title        published_at  \
# ...

# %%
# Q 14 answer
print("total number of published video count in January:", len(january_videos_info))
# Out:
# total number of published video count in January: 2108
